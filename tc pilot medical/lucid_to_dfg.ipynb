# %%
# (auto-reload changes from imported libraries)

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
from datetime import date
from IPython.display import Markdown, display
import matplotlib.pyplot as plt
import seaborn as sns
import pm4py
from pm4py.visualization.dfg import visualizer as dfg_visualizer

# %%
graph = pd.read_csv("./TC_Pilot Meds_3. Review and Assessment(Phases and statuses) - connected.csv")

# %%
from convert_to_dfg import lucid_to_dfg

dfg = lucid_to_dfg(graph, "Medical Exam complete")
print(dfg)

with open("tc_medical_cert-normative-align.py", "a") as file:
    file.write(str(dfg))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from convert_to_dfg import lucid_to_dfg
# ----> 3 dfg = lucid_to_dfg(graph, "Medical Exam complete")
#       4 print(dfg)
#       6 with open("tc_medical_cert-normative-align.py", "a") as file:
#
# NameError: name 'graph' is not defined

# %%
dfg_visualizer.apply(dfg)
